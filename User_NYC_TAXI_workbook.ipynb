# %% [markdown]
# # Import Statements
# Add libraries you like and look at already imported libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Milestone 1 -Data Exploration

# %% [markdown]
# ## Task 1 - Import Data

# %% [markdown]
# Please do not perform any sort of analysis (it's the next step!)<br>
# (HINT: The file is csv and pandas is already imported)
#
#
# ---
#
# <font size = "4"> Sanity Check
#
# The df.head() should look like this
# ![Milestone1-task1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Task 2 - Exploratory analysis on data
# <font size="3">Use functions (such as describe, count, head) to understand the start data

# %% [markdown]
# ### Multiple choice
#
# Of the 4 cleaning, which are the only two required? (Enter your answer as "ab" in the code cell below and run) <br />
# **a)** Remove non integer passenger count <br />
# **b)** Remove negative fare amounts <br />
# **c)** Remove longitudes outside NYC <br />
# **d)** Remove negative pickup_longitude <br />

# %% [markdown]
# # Milestone 2 - Cleaning dataset

# %% [markdown]
# ## Task - 3 Remove values in with negative or null data
# 1. Values where fare amount < 0
# 2. Passenger count <= 0
# 3. Any field that has any value missing
# ---
#
# ### HINTS
# Documentation to drop null elements in pandas https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html <br />
# Remember that most of the operations on dataframes are out of place!
#
# ---
# ### Sanity Check
# The length of the final dataset should be 12729
#
# ---

# %% [markdown]
# # Milestone 3 - Removing data points which lie outside of NYC latitutes

# %% [markdown]
# ## Task 4 - Corners of the area
# Find the minmum and maximum latitude and longitude points in the dataframe
#
# ---
#
# HINT:
# The dataframe consists of two columns -- pickup and dropoff points <br/>
#
# ---
# Sanity Check - maximum latitude is 401.08332

# %% [markdown]
# ## Task 5 - Dropping undesired location rows

# %% [markdown]
# Given that the desired area of concern is within -74.5 < `longitude` < -72.8 and  40.5 < `latitude` < 41.8. Remove the latitudes and longitudes that lie outside this area. <br>
# Think if your above result provide any information to filter the dataframe by?
# ---
#
# Sanity Check - you will be dropping 250 rows

# %% [markdown]
# # Milestone 4 - Fare from anywhere to JFK

# %% [markdown]
# ## Task 6 - Testing hypothesis
#
# A local Uber enthusiast claims that all travel to and from JFK (an airport at NYC) has the same cost. <br> Given that JFK is between (latitudes longitudes) (40.644633, -73.795537) and (40.645848, -73.771921) verify if their claim is correct or not? If it is not, plot the distribution of cost vs distance. <br> <br> HINT: Do not perform want inplace operations. <br> Did task 5 asked you to do something similar? <br> Take a sneek peak to the next sanity check question <br> Note that to convert latitudes and longitudes to actual distance, you can use this formula = `np.sqrt(((new_df['pickup_latitude'] - new_df['dropoff_latitude']) * 69)**2 + ((new_df['pickup_longitude'] - new_df['dropoff_longitude']) * 54.6) ** 2)`
#
#
#
# ---
#
# Sanity check - a scatter plot should look like <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Sanity check
# Think about how many unique fare amount values are there?

# %% [markdown]
# ## Final
# Please run the commands below and follow the instructions carefully

# %%
import codecs

jupyter_file = codecs.open("User_NYC_TAXI_workbook.ipynb", 'r')
source_data = jupyter_file.read()

f = open("submit.json", "w")
f.write(source_data)
f.close()

# %%
f = open("in_file.txt", "a")
for i in In:
    f.write(i)
    f.write('\n')
f.close()
